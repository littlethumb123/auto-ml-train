# %% [markdown]
# # 1. Vertex AI SDK missing output_uri parameter for Mistral fine-tuning

# %%
from vertexai.tuning import sft
import vertexai

vertexai.init(project='anbc-dev-hcm-cm-de', location='us-central1')

train_data = 'peft_train_sample'
eval_data = 'peft_eval_sample'

sft_tuning_job = sft.train(
    source_model="mistralai/ministral-3@latest",
    train_dataset=f"gs://hcm-cm-de-data-hcb-dev/zj_a455644_test/{train_data}.jsonl",
    validation_dataset=f"gs://hcm-cm-de-data-hcb-dev/zj_a455644_test/{eval_data}.jsonl",
    epochs=1,
    tuned_model_display_name="my-tuned-mistral",
)
# Out:
# Creating SupervisedTuningJob
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
# ...

# %% [markdown]
# # 2. Grant Vertex AI Tuning Access to GCS Bucket

# %%
from vertexai.tuning import sft
import vertexai

vertexai.init(project='anbc-dev-hcm-cm-de', location='us-central1')

train_data = 'peft_train_sample_gemini'
eval_data = 'peft_eval_sample_gemini'

sft_tuning_job = sft.train(
    source_model="gemini-2.0-flash-001",
    train_dataset=f"gs://hcm-cm-de-data-hcb-dev/zj_a455644_test/{train_data}.jsonl",
    validation_dataset=f"gs://hcm-cm-de-data-hcb-dev/zj_a455644_test/{eval_data}.jsonl",
    epochs=1,
    tuned_model_display_name="my-tuned-gemini",
)
# Out:
# Creating SupervisedTuningJob
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File /opt/conda/lib/python3.10/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
# ...

# %% [markdown]
# # Current env for reference

# %%
# Get version info
import vertexai
import google.cloud.aiplatform as aiplatform

print(f"Vertex AI SDK version: {aiplatform.__version__}")
print(f"Project: anbc-dev-hcm-cm-de")
print(f"Location: us-central1")
print(f"Bucket: gs://hcm-cm-de-data-hcb-dev")
# Out:
# Vertex AI SDK version: 1.97.0
# Project: anbc-dev-hcm-cm-de
# Location: us-central1
# Bucket: gs://hcm-cm-de-data-hcb-dev
